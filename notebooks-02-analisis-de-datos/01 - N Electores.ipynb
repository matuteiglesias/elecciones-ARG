# %% [markdown]
# # Numero de electores por circuito electoral.
#
# Este notebook presenta un análisis del número de votantes por circuito electoral en Argentina, utilizando datos de las últimas elecciones nacionales. El análisis incluye el número de electores por circuito, así como el número de votos por cada tipo de elección, cargo y partido político.
#
# ## Contenidos
#
# - Fuentes de datos y preparación
# - Número de votantes por circuito
# - Número de votos por tipo de elección
# - Número de votos por cargo
# - Número de votos por partido político

# %%
# Importing necessary libraries
import warnings
import pandas as pd
import glob

# Ignoring warnings
warnings.filterwarnings("ignore")
pd.options.display.max_rows = 99

# %% [markdown]
# ## Mesas

# %%
import pandas as pd
df_mesas = pd.read_csv('./../datos/BD/mesas_table.csv')
# df_mesas = df_mesas.groupby(['eleccion_id', 'distrito_id', 'seccion_id', 'circuito_id', 'mesa_id'])['mesa_electores'].first().reset_index()
# Hay un problema con la columna mesa tipo, que falta completar en las elecciones 3, 9, 10
# Por eso, tiramos mesa tipo, y hacemos un groupby-first por el resto de las columnas, 

## Hay un problema en los datos originales de la eleccion de 2017. (8	2017	GENERAL	PROVISORIO	NORMAL)
## La solucion seria que dentro de un distrito, y circuito, los numeros de mesa de la eleccion (8	2017	GENERAL	PROVISORIO	NORMAL) serian los de la (7	2017	GENERAL	PROVISORIO	COMANDO)
fix_copy = df_mesas.loc[df_mesas.eleccion_id == 7].copy()
fix_copy['eleccion_id'] = 8

df_mesas = df_mesas.loc[df_mesas.eleccion_id != 8]
df_mesas = pd.concat([df_mesas, fix_copy])

## Revisar tambien problemas por los cuales hya mesas con cero votos en algunas elecciones.

# %%
df_mesas
# Out:
#         eleccion_id  distrito_id  seccion_id circuito_id  mesa_id  \
# 0                 1            1          15      000161     6883
# 1                 1            1          15      000161     6901
# 2                 1            1          15      000161     6914
# 3                 1            1          15      000159     6813
# 4                 1            1          15      000162     6951
# ...             ...          ...         ...         ...      ...
# 452762            8           24           3      000023      462
# 452763            8           24           3      000024      463
# 452764            8           24           3      000025      464
# 452765            8           24           3      000027      465
# 452766            8           24           3      000028      466
#
#         mesa_electores mesa_tipo
# 0                346.0   NATIVOS
# 1                346.0   NATIVOS
# 2                345.0   NATIVOS
# 3                346.0   NATIVOS
# 4                345.0   NATIVOS
# ...                ...       ...
# 452762            42.0   NATIVOS
# 452763            40.0   NATIVOS
# 452764            22.0   NATIVOS
# 452765            22.0   NATIVOS
# 452766             2.0   NATIVOS
#
# [1573727 rows x 7 columns]

# %%
# ### Para ver ese problema las siguientes tablitas. Parece que hay numeros de mesa de 2013 que por alguna razon se copiaron a 2017 pero no deberian. 

# import glob
# # Define the glob pattern to find the CSV files
# csv_votos_pattern = './../datos/Solo_ResultadosProvisorios/**/*.csv'

# # Find all the CSV files that match the glob pattern
# csv_votos_files = glob.glob(csv_votos_pattern, recursive=True)


# df = pd.DataFrame()
# for file in csv_votos_files:
#     print(file)
#     part = pd.read_csv(file)
#     part = part.loc[(part.distrito_id == 3)]
#     # concatenate
#     df = pd.concat([df, part], axis=0)


# table = df.loc[(df.distrito_id == 3) & (df.circuito_id == '0031')][['año', 'eleccion_tipo', 'padron_tipo', 'mesa_id']].drop_duplicates()
# table[1] = '1'

# table.set_index(['año', 'eleccion_tipo', 'padron_tipo', 'mesa_id']).unstack().fillna('')


# table = df.loc[(df.distrito_id == 3) & (df.circuito_id == '0058')][['año', 'eleccion_tipo', 'padron_tipo', 'mesa_id']].drop_duplicates()
# table[1] = '1'

# table.set_index(['año', 'eleccion_tipo', 'padron_tipo', 'mesa_id']).unstack().fillna('')

# %%
pd.options.display.float_format = '{:.1f}'.format

# %%
elecciones = pd.read_csv('./../datos/BD/eleccion_table.csv')
info = (df_mesas.merge(elecciones).groupby(['eleccion_id', 'eleccion_tipo', 'año', 'padron_tipo', 'distrito_id']).agg({'mesa_electores': 'sum'}).unstack()/1e4)

pd.options.display.max_columns = 30
def apply_gradient(df):
    return df.style.background_gradient(cmap='RdYlGn', vmin=0.5, vmax=1.5).format(' {:.2f}')

show = info.div(info.median(0), 1).round(2)

styled_df = apply_gradient(show)
styled_df
# Out:
# <style type="text/css">
# #T_35f3b_row0_col0, #T_35f3b_row4_col2, #T_35f3b_row4_col12, #T_35f3b_row5_col1, #T_35f3b_row5_col10, #T_35f3b_row5_col12, #T_35f3b_row6_col3, #T_35f3b_row6_col12, #T_35f3b_row6_col16, #T_35f3b_row11_col1 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_35f3b_row0_col1, #T_35f3b_row0_col5, #T_35f3b_row0_col10, #T_35f3b_row2_col13, #T_35f3b_row2_col23, #T_35f3b_row3_col13, #T_35f3b_row3_col15, #T_35f3b_row3_col21, #T_35f3b_row3_col23, #T_35f3b_row5_col2, #T_35f3b_row5_col7, #T_35f3b_row5_col9 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_35f3b_row0_col2 {
#   background-color: #fed07e;
#   color: #000000;
# }
# #T_35f3b_row0_col3, #T_35f3b_row0_col4, #T_35f3b_row0_col12 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_35f3b_row0_col6, #T_35f3b_row0_col17, #T_35f3b_row0_col22 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_35f3b_row0_col7 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_35f3b_row0_col8 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_35f3b_row0_col9, #T_35f3b_row0_col19 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_35f3b_row0_col11, #T_35f3b_row0_col14 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_35f3b_row0_col13 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_35f3b_row0_col15, #T_35f3b_row0_col16, #T_35f3b_row0_col18, #T_35f3b_row0_col21 {
#   background-color: #fdb365;
#   color: #000000;
# }
# #T_35f3b_row0_col20, #T_35f3b_row2_col8, #T_35f3b_row2_col9, #T_35f3b_row2_col14, #T_35f3b_row2_col15, #T_35f3b_row2_col18, #T_35f3b_row2_col21, #T_35f3b_row2_col22, #T_35f3b_row3_col8, #T_35f3b_row3_col9, #T_35f3b_row3_col11, #T_35f3b_row3_col14, #T_35f3b_row3_col18, #T_35f3b_row3_col19, #T_35f3b_row3_col22 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_35f3b_row0_col23 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_35f3b_row1_col0 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_35f3b_row1_col1 {
#   background-color: #e24731;
#   color: #f1f1f1;
# }
# #T_35f3b_row1_col2, #T_35f3b_row1_col4, #T_35f3b_row1_col5, #T_35f3b_row1_col7, #T_35f3b_row1_col8, #T_35f3b_row1_col9, #T_35f3b_row1_col12, #T_35f3b_row1_col16, #T_35f3b_row1_col17, #T_35f3b_row1_col18, #T_35f3b_row1_col21, #T_35f3b_row1_col22, #T_35f3b_row11_col23 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_35f3b_row1_col3, #T_35f3b_row1_col15 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_35f3b_row1_col6 {
#   background-color: #a90426;
#   color: #f1f1f1;
# }
# #T_35f3b_row1_col10 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_35f3b_row1_col11 {
#   background-color: #b30d26;
#   color: #f1f1f1;
# }
# #T_35f3b_row1_col13 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_35f3b_row1_col14 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_35f3b_row1_col19 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_35f3b_row1_col20 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_35f3b_row1_col23 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_35f3b_row2_col0, #T_35f3b_row3_col0, #T_35f3b_row4_col0, #T_35f3b_row4_col4, #T_35f3b_row4_col5, #T_35f3b_row5_col4, #T_35f3b_row6_col1, #T_35f3b_row6_col4, #T_35f3b_row6_col5, #T_35f3b_row7_col0, #T_35f3b_row7_col3, #T_35f3b_row7_col7, #T_35f3b_row7_col8, #T_35f3b_row7_col9, #T_35f3b_row7_col11, #T_35f3b_row7_col12, #T_35f3b_row7_col13, #T_35f3b_row7_col14, #T_35f3b_row7_col15, #T_35f3b_row7_col17, #T_35f3b_row7_col18, #T_35f3b_row7_col19, #T_35f3b_row7_col20, #T_35f3b_row7_col21, #T_35f3b_row7_col22, #T_35f3b_row7_col23, #T_35f3b_row8_col0, #T_35f3b_row8_col3, #T_35f3b_row8_col7, #T_35f3b_row8_col8, #T_35f3b_row8_col9, #T_35f3b_row8_col11, #T_35f3b_row8_col12, #T_35f3b_row8_col13, #T_35f3b_row8_col14, #T_35f3b_row8_col15, #T_35f3b_row8_col17, #T_35f3b_row8_col18, #T_35f3b_row8_col19, #T_35f3b_row8_col20, #T_35f3b_row8_col21, #T_35f3b_row8_col22, #T_35f3b_row8_col23, #T_35f3b_row9_col0, #T_35f3b_row9_col3, #T_35f3b_row9_col7, #T_35f3b_row9_col8, #T_35f3b_row9_col9, #T_35f3b_row9_col11, #T_35f3b_row9_col12, #T_35f3b_row9_col13, #T_35f3b_row9_col14, #T_35f3b_row9_col15, #T_35f3b_row9_col17, #T_35f3b_row9_col18, #T_35f3b_row9_col20, #T_35f3b_row9_col21, #T_35f3b_row9_col22, #T_35f3b_row9_col23, #T_35f3b_row10_col0, #T_35f3b_row10_col3, #T_35f3b_row10_col7, #T_35f3b_row10_col8, #T_35f3b_row10_col9, #T_35f3b_row10_col11, #T_35f3b_row10_col12, #T_35f3b_row10_col13, #T_35f3b_row10_col14, #T_35f3b_row10_col15, #T_35f3b_row10_col17, #T_35f3b_row10_col18, #T_35f3b_row10_col20, #T_35f3b_row10_col21, #T_35f3b_row10_col22, #T_35f3b_row10_col23, #T_35f3b_row11_col6, #T_35f3b_row11_col10, #T_35f3b_row11_col12, #T_35f3b_row11_col13, #T_35f3b_row11_col16, #T_35f3b_row12_col0, #T_35f3b_row12_col6, #T_35f3b_row12_col10, #T_35f3b_row12_col11, #T_35f3b_row12_col12, #T_35f3b_row12_col13, #T_35f3b_row12_col16, #T_35f3b_row13_col2, #T_35f3b_row13_col19, #T_35f3b_row14_col2, #T_35f3b_row14_col19 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_35f3b_row2_col1, #T_35f3b_row2_col2, #T_35f3b_row2_col4, #T_35f3b_row2_col5, #T_35f3b_row3_col2, #T_35f3b_row3_col4, #T_35f3b_row3_col5, #T_35f3b_row4_col1, #T_35f3b_row4_col7, #T_35f3b_row4_col8, #T_35f3b_row4_col11, #T_35f3b_row4_col15, #T_35f3b_row4_col17, #T_35f3b_row4_col19, #T_35f3b_row4_col21, #T_35f3b_row5_col15, #T_35f3b_row5_col16, #T_35f3b_row5_col21, #T_35f3b_row5_col22, #T_35f3b_row5_col23, #T_35f3b_row6_col7, #T_35f3b_row6_col8, #T_35f3b_row6_col11, #T_35f3b_row6_col13, #T_35f3b_row6_col21 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_35f3b_row2_col3, #T_35f3b_row3_col3, #T_35f3b_row4_col16, #T_35f3b_row5_col6, #T_35f3b_row5_col13, #T_35f3b_row11_col4, #T_35f3b_row12_col4, #T_35f3b_row13_col5, #T_35f3b_row14_col5 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_35f3b_row2_col6, #T_35f3b_row2_col7, #T_35f3b_row2_col11, #T_35f3b_row2_col17, #T_35f3b_row3_col7, #T_35f3b_row3_col17 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_35f3b_row2_col10, #T_35f3b_row2_col20, #T_35f3b_row3_col1, #T_35f3b_row3_col10, #T_35f3b_row3_col20, #T_35f3b_row4_col13, #T_35f3b_row4_col18, #T_35f3b_row5_col11, #T_35f3b_row5_col17, #T_35f3b_row6_col9, #T_35f3b_row6_col15 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_35f3b_row2_col12, #T_35f3b_row3_col12, #T_35f3b_row4_col9, #T_35f3b_row5_col18, #T_35f3b_row5_col19, #T_35f3b_row6_col18 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_35f3b_row2_col16, #T_35f3b_row2_col19, #T_35f3b_row3_col6, #T_35f3b_row3_col16 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_35f3b_row4_col3, #T_35f3b_row4_col6, #T_35f3b_row4_col14, #T_35f3b_row4_col22, #T_35f3b_row4_col23, #T_35f3b_row5_col3, #T_35f3b_row5_col14, #T_35f3b_row6_col6, #T_35f3b_row6_col14, #T_35f3b_row6_col17, #T_35f3b_row6_col19, #T_35f3b_row6_col22, #T_35f3b_row6_col23 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_35f3b_row4_col10, #T_35f3b_row5_col5, #T_35f3b_row5_col20, #T_35f3b_row6_col10 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_35f3b_row4_col20, #T_35f3b_row5_col0, #T_35f3b_row6_col0, #T_35f3b_row6_col20, #T_35f3b_row13_col1 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_35f3b_row5_col8 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_35f3b_row6_col2 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_35f3b_row7_col1, #T_35f3b_row8_col1, #T_35f3b_row9_col1, #T_35f3b_row10_col1, #T_35f3b_row15_col10, #T_35f3b_row15_col11, #T_35f3b_row16_col10, #T_35f3b_row16_col11 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_35f3b_row7_col2, #T_35f3b_row7_col5, #T_35f3b_row8_col2, #T_35f3b_row8_col5, #T_35f3b_row9_col2, #T_35f3b_row9_col5, #T_35f3b_row10_col2, #T_35f3b_row10_col5, #T_35f3b_row15_col1, #T_35f3b_row15_col14, #T_35f3b_row15_col23, #T_35f3b_row16_col1, #T_35f3b_row16_col14, #T_35f3b_row16_col23 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_35f3b_row7_col4, #T_35f3b_row8_col4, #T_35f3b_row9_col4, #T_35f3b_row10_col4, #T_35f3b_row14_col1, #T_35f3b_row15_col2, #T_35f3b_row15_col8, #T_35f3b_row15_col9, #T_35f3b_row15_col13, #T_35f3b_row15_col16, #T_35f3b_row15_col21,

# %%
## Hay faltante importante con la de 2011 PASO, y a COMANDO 2019 le faltan algunas provincias

# %% [markdown]
# ## Número de electores

# %%
## Agrupar por sección y tipo de elección
import os
if not os.path.exists('./../datos/out/n_electores_dpto.csv'):
    n_electores_dpto = df_mesas.groupby(['eleccion_id', 'distrito_id', 'seccion_id']
                                            ).agg({'mesa_electores': ['sum', 'size']}).reset_index()
    n_electores_dpto.to_csv('./../datos/out/n_electores_dpto.csv', index = False)

## Agrupar por circuito y tipo de elección
if not os.path.exists('./../datos/out/n_electores_circ.csv'):
    n_electores_circ = df_mesas.groupby(['eleccion_id', 'distrito_id', 'seccion_id', 'circuito_id']
                                            ).agg({'mesa_electores': ['sum', 'size']}).reset_index()
    n_electores_circ.to_csv('./../datos/out/n_electores_circ.csv', index = False)

# %% [markdown]
# ## Número de votos por tipo de voto

# %%
import glob
import pandas as pd

csv_votos = glob.glob('./../datos/BD/votos_eleccion_*_table.csv', recursive=True)
usecols = ['distrito_id', 'votos_tipo', 'mesa_id', 'cargo_id', 'circuito_id', 'seccion_id', 'seccionprovincial_id', 'votos_cantidad', 'eleccion_id']

df = pd.DataFrame()
for file in csv_votos:
    part = pd.read_csv(file, usecols=usecols)
    print(file, part.shape, part.votos_cantidad.sum())

    if file == './../datos/BD/votos_eleccion_8_table.csv':
        ## Necesitamos hacer este merge para transladar la correccion de mesas "duplicadas" de 2017 del dataset de mesas al de votos
        part = df_mesas.loc[df_mesas.eleccion_id == 8][['eleccion_id', 'distrito_id', 'seccion_id', 'circuito_id', 'mesa_id']].merge(part.fillna(0), how = 'left')   ## Elecciones 6, 3, 10, 2, 16 tienen algo con este merge...
        print(file, part.shape, part.votos_cantidad.sum())

    # concatenate
    df = pd.concat([df, part])
# Out:
# ./../datos/BD/votos_eleccion_5_table.csv (5053072, 9) 144522104
# ./../datos/BD/votos_eleccion_8_table.csv (2438892, 9) 61800457
# ./../datos/BD/votos_eleccion_8_table.csv (2108825, 9) 56526779
# ./../datos/BD/votos_eleccion_1_table.csv (2116876, 9) 37294635
# ./../datos/BD/votos_eleccion_4_table.csv (565020, 9) 25738560
# ./../datos/BD/votos_eleccion_6_table.csv (8956666, 9) 128463868
# ./../datos/BD/votos_eleccion_11_table.csv (264145, 9) 48043
# ./../datos/BD/votos_eleccion_3_table.csv (2277250, 9) 35291518
# ./../datos/BD/votos_eleccion_15_table.csv (230717, 9) 24960
# ./../datos/BD/votos_eleccion_12_table.csv (3159297, 9) 95811610
# ./../datos/BD/votos_eleccion_10_table.csv (4807171, 9) 49410512
# ./../datos/BD/votos_eleccion_0_table.csv (3503909, 9) 84365358
# ./../datos/BD/votos_eleccion_14_table.csv (5082019, 9) 89203585
# ./../datos/BD/votos_eleccion_2_table.csv (1697141, 9) 45336513
# ./../datos/BD/votos_eleccion_13_table.csv (303176, 9) 57822
# ./../datos/BD/votos_eleccion_9_table.csv (153773, 9) 88203
# ./../datos/BD/votos_eleccion_16_table.csv (5214490, 9) 52734617
# ./../datos/BD/votos_eleccion_7_table.csv (204116, 9) 60722

# %%
# Debug
# csvs = ['./../datos/BD/votos_eleccion_3_table.csv',
# './../datos/BD/votos_eleccion_10_table.csv',
# './../datos/BD/votos_eleccion_2_table.csv',
# './../datos/BD/votos_eleccion_16_table.csv',
# './../datos/BD/votos_eleccion_6_table.csv']


# for file in csvs:
#     part = pd.read_csv(file)
#     print(file, part.shape)
#     ## Necesitamos hacer este merge para transladar la correccion de mesas "duplicadas" de 2017 del dataset de mesas al de votos
#     part1 = df_mesas[['eleccion_id', 'distrito_id', 'seccion_id', 'circuito_id', 'mesa_id']].merge(part, how = 'left').dropna()
#     part2 = df_mesas[['eleccion_id', 'distrito_id', 'seccion_id', 'circuito_id', 'mesa_id']].merge(part, how = 'left').dropna().drop_duplicates()
#     part3 = df_mesas[['eleccion_id', 'distrito_id', 'seccion_id', 'circuito_id', 'mesa_id']].drop_duplicates().merge(part, how = 'left').dropna()
#     print(file, part1.shape)
#     print(file, part2.shape)
#     print(file, part3.shape)
# Out:
# ./../datos/BD/votos_eleccion_3_table.csv (2277250, 11)
# ./../datos/BD/votos_eleccion_3_table.csv (1477150, 11)
# ./../datos/BD/votos_eleccion_3_table.csv (1477150, 11)
# ./../datos/BD/votos_eleccion_3_table.csv (1477150, 11)
# ./../datos/BD/votos_eleccion_10_table.csv (4807171, 11)
# ./../datos/BD/votos_eleccion_10_table.csv (3805475, 11)
# ./../datos/BD/votos_eleccion_10_table.csv (3805475, 11)
# ./../datos/BD/votos_eleccion_10_table.csv (3805475, 11)
# ./../datos/BD/votos_eleccion_2_table.csv (1697141, 11)
# ./../datos/BD/votos_eleccion_2_table.csv (0, 11)
# ./../datos/BD/votos_eleccion_2_table.csv (0, 11)
# ./../datos/BD/votos_eleccion_2_table.csv (0, 11)
# ./../datos/BD/votos_eleccion_16_table.csv (5214490, 11)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_73413/3052892650.py in <module>
#      10     print(file, part.shape)
#      11     ## Necesitamos hacer este merge para transladar la correccion de mesas "duplicadas" de 2017 del dataset de mesas al de votos
# ---> 12     part1 = df_mesas[['eleccion_id', 'distrito_id', 'seccion_id', 'circuito_id', 'mesa_id']].merge(part, how = 'left').dropna()
#      13     part2 = df_mesas[['eleccion_id', 'distrito_id', 'seccion_id', 'circuito_id', 'mesa_id']].merge(part, how = 'left').dropna().drop_duplicates()
#      14     part3 = df_mesas[['eleccion_id', 'distrito_id', 'seccion_id', 'circuito_id', 'mesa_id']].drop_duplicates().merge(part, how = 'left').dropna()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    6017         elif how == "any":
#    6018             # faster equivalent to 'agg_obj.count(agg_axis) == self.shape[agg_axis]'
# -> 6019             mask = notna(agg_obj).all(axis=agg_axis, bool_only=False)
#    6020         elif how == "all":
#    6021             # faster equivalent to 'agg_obj.count(agg_axis) > 0'
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in notna(obj)
#     363     Name: 1, dtype: bool
#     364     """
# --> 365     res = isna(obj)
#     366     if is_scalar(res):
#     367         return not res
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#     142     Name: 1, dtype: bool
#     143     """
# --> 144     return _isna(obj)
#     145
#     146
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in _isna(obj, inf_as_na)
#     185         return result
#     186     elif isinstance(obj, ABCDataFrame):
# --> 187         return obj.isna()
#     188     elif isinstance(obj, list):
#     189         return _isna_array(np.asarray(obj, dtype=object), inf_as_na=inf_as_na)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in isna(self)
#    5859     @doc(NDFrame.isna, klass=_shared_doc_kwargs["klass"])
#    5860     def isna(self) -> DataFrame:
# -> 5861         result = self._constructor(self._mgr.isna(func=isna))
#    5862         return result.__finalize__(self, method="isna")
#    5863
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py in isna(self, func)
#     143     @final
#     144     def isna(self: T, func) -> T:
# --> 145         return self.apply("apply", func=func)
#     146
#     147     # --------------------------------------------------------------------
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     400         one
#     401         """
# --> 402         result = func(self.values, **kwargs)
#     403
#     404         return self._split_op_result(result)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in isna(obj)
#     142     Name: 1, dtype: bool
#     143     """
# --> 144     return _isna(obj)
#     145
#     146
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in _isna(obj, inf_as_na)
#     171         return False
#     172     elif isinstance(obj, (np.ndarray, ABCExtensionArray)):
# --> 173         return _isna_array(obj, inf_as_na=inf_as_na)
#     174     elif isinstance(obj, ABCIndex):
#     175         # Try to use cached isna, which also short-circuits for integer dtypes
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in _isna_array(values, inf_as_na)
#     253             result = values.isna()  # type: ignore[assignment]
#     254     elif is_string_or_object_np_dtype(values.dtype):
# --> 255         result = _isna_string_dtype(values, inf_as_na=inf_as_na)
#     256     elif needs_i8_conversion(dtype):
#     257         # this is the NaT pattern
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py in _isna_string_dtype(values, inf_as_na)
#     277             result = libmissing.isnaobj(values, inf_as_na=inf_as_na)
#     278         elif values.ndim == 2:
# --> 279             result = libmissing.isnaobj2d(values, inf_as_na=inf_as_na)
#     280         else:
#     281             # 0-D, reached via e.g. mask_missing
#
# KeyboardInterrupt:

# %%
## Para Votos Tipo
# Agrupar por: 'cargo_id', 'seccion_id', 'distrito_id', 'votos_tipo'
# Despues agregar circuito id, despues agregar tambien mesa_id, para tener las tablas por circuito y mesa

import os
## Agrupar por sección y tipo de elección
if not os.path.exists('./../datos/out/votos_tipo_dpto.csv'):
    votos_tipo_dpto = df.groupby(['eleccion_id', 'cargo_id', 'distrito_id', 'seccionprovincial_id', 'seccion_id', 'votos_tipo']
                                            ).agg({'votos_cantidad': 'sum'}).reset_index()
    votos_tipo_dpto.to_csv('./../datos/out/votos_tipo_dpto.csv', index = False)

## Agrupar por circuito y tipo de elección
if not os.path.exists('./../datos/out/votos_tipo_circ.csv'):
    votos_tipo_circ = df.groupby(['eleccion_id', 'cargo_id', 'distrito_id', 'seccionprovincial_id', 'seccion_id', 'circuito_id', 'votos_tipo']
                                            ).agg({'votos_cantidad': 'sum'}).reset_index()
    votos_tipo_circ.to_csv('./../datos/out/votos_tipo_circ.csv', index = False)

## Agrupar por mesa y tipo de elección
if not os.path.exists('./../datos/out/votos_tipo_mesa.csv'):
    votos_tipo_mesa = df.groupby(['eleccion_id', 'cargo_id', 'distrito_id', 'seccionprovincial_id', 'seccion_id', 'circuito_id', 'mesa_id', 'votos_tipo']
                                            ).agg({'votos_cantidad': 'sum'}).reset_index()
    votos_tipo_mesa.to_csv('./../datos/out/votos_tipo_mesa.csv', index = False)

    # , 'agrupacion_id', 'lista_numero'
