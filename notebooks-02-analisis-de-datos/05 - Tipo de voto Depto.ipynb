# %%
### Repetir esto mismo pero en circuitos...

# %%
import pandas as pd

# %%
## Los circuitos vienen identificados por las siguientes columnas
gr_circuito = ['distrito_id', 'circuito_id']
gr_seccion = ['distrito_id', 'seccion_id']

## Las elecciones vienen identificadas por lo siguiente:
gr_eleccion = ['Año', 'eleccion_tipo', 'recuento_tipo', 'padron_tipo']

gr_secprov = ['seccionprovincial_id']

## Columnas cargo y agrupacion
gr_cargo = ['cargo_id', 'cargo_nombre']
gr_agrup = ['agrupacion_id', 'agrupacion_nombre']
votos_cols = ['votos_tipo', 'votos_cantidad']

# %%
elecciones_ppales = pd.read_csv('./../datos/elecciones_ppales.csv')
elecciones_ppales
# Out:
#      Año eleccion_tipo recuento_tipo padron_tipo  cargo_id  \
# 0   2013       GENERAL    PROVISORIO      NORMAL         3
# 1   2015     BALLOTAGE    PROVISORIO      NORMAL         1
# 2   2015       GENERAL    PROVISORIO      NORMAL         1
# 3   2015       GENERAL    PROVISORIO      NORMAL         3
# 4   2015       GENERAL    PROVISORIO      NORMAL         8
# 5   2015       GENERAL    PROVISORIO      NORMAL         9
# 6   2015          PASO    PROVISORIO      NORMAL         1
# 7   2015          PASO    PROVISORIO      NORMAL         3
# 8   2015          PASO    PROVISORIO      NORMAL         8
# 9   2017       GENERAL    PROVISORIO      NORMAL         3
# 10  2017          PASO    PROVISORIO      NORMAL         3
# 11  2019       GENERAL    PROVISORIO      NORMAL         1
# 12  2019       GENERAL    PROVISORIO      NORMAL         3
# 13  2019          PASO    PROVISORIO      NORMAL         1
# 14  2019          PASO    PROVISORIO      NORMAL         3
# 15  2021          PASO    PROVISORIO      NORMAL         3
#
#                             cargo_nombre
# 0                   DIPUTADOS NACIONALES
# 1                             PRESIDENTE
# 2                             PRESIDENTE
# 3                   DIPUTADOS NACIONALES
# 4     PARLAMENTARIOS MERCOSUR NACIONALES
# 5   PARLAMENTARIOS MERCOSUR PROVINCIALES
# 6                             PRESIDENTE
# 7                   DIPUTADOS NACIONALES
# 8     PARLAMENTARIOS MERCOSUR NACIONALES
# 9                   DIPUTADOS NACIONALES
# 10                  DIPUTADOS NACIONALES
# 11                            PRESIDENTE
# 12                  DIPUTADOS NACIONALES
# 13                            PRESIDENTE
# 14                  DIPUTADOS NACIONALES
# 15                  DIPUTADOS NACIONALES

# %%
# elecciones_ppales.merge(votos_tipo_dpto, how = 'left')

# %%
votos_tipo_dpto = pd.read_csv('votos_tipo_dpto.csv')

df1 = elecciones_ppales.merge(votos_tipo_dpto, how = 'left')#.set_index(gr_eleccion + gr_cargo + gr_seccion)


electores_dpto = pd.read_csv('n_electores_dpto.csv')
df2 = elecciones_ppales.merge(electores_dpto, how = 'left')

df = pd.concat([df1, df2])

df['votos_tipo'] = df['votos_tipo'].fillna('ELECTORES')
df['votos_cantidad_sum'] = df['votos_cantidad_sum'].fillna(df.mesa_electores_sum)

df = df.drop(['mesa_electores_sum'], axis = 1)

# %%
# votos_tipo_dpto

# %%
# proy_pop = pd.read_csv('./../datos/proy_pop200125.csv', index_col=0)

radio_ref = pd.read_csv('./../datos/radio_ref.csv', index_col=0) 
p02 = pd.read_csv('./../datos/PERSONA-P02.csv', index_col=0, encoding = 'latin-1')
radios = radio_ref.merge(p02.reset_index())

dptos_p2010 = radios.groupby(['DPTO', 'NOMDPTO', 'NOMPROV'])[p02.columns].sum().reset_index()

# %%
df.columns
# Out:
# Index(['Año', 'eleccion_tipo', 'recuento_tipo', 'padron_tipo', 'cargo_id',
#        'cargo_nombre', 'distrito_id', 'seccion_id', 'seccion_nombre',
#        'votos_tipo', 'votos_cantidad_sum'],
#       dtype='object')

# %%
secciones_departamentos = pd.read_csv('./../datos/secciones_departamentos-TTGL.csv')

# %%
corregir_nombres = {'Comuna 1': 'Comuna 01',
 'Comuna 2': 'Comuna 02',
 'Comuna 3': 'Comuna 03',
 'Comuna 4': 'Comuna 04',
 'Comuna 5': 'Comuna 05',
 'Comuna 6': 'Comuna 06',
 'Comuna 7': 'Comuna 07',
 'Comuna 8': 'Comuna 08',
 'Comuna 9': 'Comuna 09',
 'Coronel De Marina L. Rosales': 'Coronel Rosales',
 'General La Madrid': 'General Lamadrid',
 'General Las Heras': 'Las Heras',
 'General Juan Madariaga': 'General Madariaga',
 'Adolfo Gonzales Chaves': 'Gonzales Chaves',
 'Guaminí': 'Guamini',
 'Benito Juárez': 'Juárez',
 'Matanza': 'La Matanza',
 'Lobería': 'Loberia',
 '9 De Julio': 'Nueve De Julio',
 'Puán': 'Puan',
 'Trenque Lauquen': 'Trenque Lauquén',
 '25 De Mayo': 'Veinticinco De Mayo',
 'Florentino Ameghino': 'F. Ameghino',
 'José C. Paz': 'J. C. Paz',
 'Ituzaingó': 'Ituzaingo',
 'Capayán': 'Capayan',
 'Paclín': 'Paclin',
 'Ischilín': 'Ischilin',
 'Presidente Roque Sáenz Peña': 'Roque Sáenz Peña',
 'Mburucuyá': 'Mburucuya',
 'Itatí': 'Itati',
 '1º De Mayo': 'Primero De Mayo',
 'Presidencia De La Plaza': 'Pcia. De La Plaza',
 'Presidencia De La  Plaza': 'Pcia. De La Plaza',
 'Libertador General San Martín': 'San Martín',
 'Libertador Gral. San Martín': 'Lib. Gral. San Martín',
 'Tapenagá': 'Tapenaga',
 'Mayor Luis J. Fontana': 'Mayor L. J. Fontana',
 'Fray Justo Santa María De Oro': 'Fray J. Sta. María De Oro',
 'Fray Justo Sta. María De Oro': 'Fray J. Sta. María De Oro',
 'Paso De Los Indios': 'Paso De Indios',
 'Río Senger': 'Río Senguer',
 'Laishí': 'Laishi',
 'Pilagás': 'Pilagas',
 'Dr. Manuel Belgrano': 'General Belgrano',
 'Atreucó': 'Atreuco',
 'Chapaleufú': 'Chapaleufu',
 'Chical Co': 'Chical-Co',
 'Chical Có': 'Chical-Co',
 'Curacó': 'Curaco',
 'Guatraché': 'Guatrache',
 'Loventué': 'Loventue',
 'Maracó': 'Maraco',
 'Puelén': 'Puelen',
 'Quemú Quemú': 'Quemu Quemu',
 'Coronel Felipe Varela': 'Felipe Varela',
 'General Angel Vicente Peñaloza': 'Angel Vicente Peñaloza',
 'Ángel Vicente Peñaloza': 'Angel Vicente Peñaloza',
 'General Juan Facundo Quiroga': 'Juan Facundo Quiroga',
 'Luján De Cuyo': 'Luján',
 'Malargüe': 'Malargue',
 'Concepción': 'Concepción De La Sierra',
 'Cainguás': 'Cainguas',
 'Eldorado': 'El Dorado',
 'General Manuel Belgrano': 'Gral. Manuel Belgrano',
 'Catán Lil': 'Catan Lil',
 'Collón Curá': 'Collon Curá',
 'San Antonio': 'San Antonio Oeste',
 'General José San Martín': 'San Martín',
 'General José De San Martín': 'San Martín',
 'Santa Lucia': 'Santa Lucía',
 'Ullum': 'Ullúm',
 'Juan Martín De Pueyrredón': 'Pueyrredon',
 'Pueyrredón': 'Pueyrredon',
 'Coronel Pringles': 'Pringles',
 'General Pedernera': 'Pedernera',
 'Villa Constitución': 'Constitución',
 'Matara': 'Juan F. Ibarra',
 'Silípica': 'Silipica',
 'General Taboada': 'Taboada',
 'Juan B. Alberdi': 'Alberdi',
 'Juan Bautista Alberdi': 'Alberdi',
 'Burruyacú': 'Burruyacu'}

# %%
pd.options.display.max_rows = 1000

# %%
## DEBUG. NOMDPTOS

ref = df1[['distrito_id', 'seccion_id', 'seccion_nombre']].drop_duplicates()
ref['seccion_nombre'] = ref['seccion_nombre'].replace(corregir_nombres)
ref = ref.drop_duplicates()

ref = ref.merge(secciones_departamentos, left_on = ['distrito_id', 'seccion_id'],
right_on = ['codprov', 'seccion_id'], how = 'inner')

# Estas son las diferencias.
diferencias = ref.loc[ref.seccion_nombre != ref.NOMDPTO]

# Principalmen/te hay problema con san juan y misiones
# diferencias.groupby(['codprov']).size()
# diferencias

# fix14 = diferencias.loc[diferencias.distrito_id == 14].to_csv('./fix14.csv')
# fix18 = diferencias.loc[diferencias.distrito_id == 18].to_csv('./fix18.csv')

# diferencias.loc[diferencias.distrito_id == 14]

diferencias
# Out:
#      distrito_id  seccion_id             seccion_nombre  codprov  coddepto  \
# 24             2          10                  Arrecifes        2        10
# 35             2          21            Carmen De Areco        2        21
# 40             2          26                   Pringles        2        26
# 41             2          27            Coronel Rosales        2        27
# 51             2          37      Exaltación De La Cruz        2        37
# 58             2          44           General Lamadrid        2        44
# 59             2          45                  Las Heras        2        45
# 61             2          47          General Madariaga        2        47
# 70             2          56            Gonzales Chaves        2        56
# 71             2          57                    Guamini        2        57
# 73             2          59                     Juárez        2        59
# 82             2          68                    Loberia        2        68
# 84             2          70            Lomas De Zamora        2        70
# 97             2          83             Nueve De Julio        2        83
# 105            2          91                       Puan        2        91
# 116            2         102        San Andrés De Giles        2       102
# 117            2         103       San Antonio De Areco        2       103
# 129            2         115            Trenque Lauquén        2       115
# 132            2         118            Tres De Febrero        2       118
# 135            2         121        Veinticinco De Mayo        2       121
# 141            2         127                F. Ameghino        2       127
# 143            2         129                  J. C. Paz        2       129
# 147            2         133                  Ituzaingo        2       133
# 149            2         135                     Lezama        2       135
# 151            3           2                    Capayan        3         2
# 160            3          11                      Pomán        3        11
# 163            3          14   Antofagasta De La Sierra        3        14
# 169            4           4               Cruz Del Eje        4         4
# 172            4           7                   Ischilin        4         7
# 182            4          17           Roque Sáenz Peña        4        17
# 199            5           8         Paso De Los Libres        5         8
# 201            5          10        San Luis Del Palmar        5        10
# 208            5          17    Concepción De La Sierra        5        17
# 209            5          18                  Mburucuya        5        18
# 210            5          19                  Ituzaingo        5        19
# 215            5          24                      Itati        5        24
# 216            5          25           Berón De Astrada        5        25
# 218            6           2            Primero De Mayo        6         2
# 222            6           6          Pcia. De La Plaza        6         6
# 224            6           8                 San Martín        6         8
# 225            6           8      Lib. Gral. San Martín        6         8
# 226            6           9                   Tapenaga        6         9
# 228            6          11        Mayor L. J. Fontana        6        11
# 232            6          15        Veinticinco De Mayo        6        15
# 236            6          19             Nueve De Julio        6        19
# 238            6          21              12 De Octubre        6        21
# 239            6          22                 2 De Abril        6        22
# 240            6          23  Fray J. Sta. María De Oro        6        23
# 251            7           9             Paso De Indios        7         9
# 252            7          10                   Mártires        7        10
# 253            7          11                F. Ameghino        7        11
# 262            8           6                     Nogoyá        8         6
# 267            8          11           Islas Del Ibicuy        8        11
# 278            9           4                     Pirané        9         4
# 279            9           5                    Pilagas        9         5
# 284           10           1           General Belgrano       10         1
# 286           10           3          San Antonio Oeste       10         3
# 298           10          15                       Yavi       10        15
# 305           11           6                 Chapaleufu       11         6
# 306           11           7                  Chical-Co       11         7
# 308           11           9                     Curaco       11         9
# 309           11          10                  Guatrache       11        10
# 311           11          12                   Loventue       11        12
# 314           11          15                     Maraco       11        15
# 315           11          16                     Puelen       11        16
# 316           11          17                Quemu Quemu       11        17
# 326           12           5     San Blas De Los Sauces       12         5
# 329           12           8              Felipe Varela       12         8
# 334           12          13     Angel Vicente Peñaloza       12        13
# 336           12          15       Juan Facundo Quiroga       12        15
# 337           12          16    General Ortiz De Ocampo       12        16
# 346           13           7                      Luján       13         7
# 356           13          17                   Malargue       13        17
# 362           14           5    Concepción De La Sierra       14         5
# 366           14           9                 San Martín       14        11
# 367           14           9      L. General San Martín       14        11
# 368           14          10                   Cainguas       14         2
# 369           14          11        Veinticinco De Mayo       14        17
# 375           14          17      Gral. Manuel Belgrano       14         7
# 388           15          13                Collon Curá       15        13
# 390           15          15                      Lácar       15        15
# 394           16           3          San Antonio Oeste       16         3
# 396           16           5             Nueve De Julio       16         5
# 397           16           6        Veinticinco De Mayo       16         6
# 399           16           8                 Pilcaniyeu       16         8
# 401           16          10              Pichi Mahuida       16        10
# 412           17           8                 San Martín       17         8
# 419           17          15     Rosario De La Frontera       17        15
# 425           17          21           Rosario De Lerma       17        21
# 434           18           7             Nueve De Julio       18         9
# 438           18          11                      Ullúm       18        16
# 441           18          14        Veinticinco De Mayo       18        18
# 447           19           1                 Pueyrredon       19         1
# 448           19           2                   Pringles       19         2
# 449           19           3                  Pedernera       19         3
# 451           19           5                 San Martín       19         5
# 473           21          12             Nueve De Julio       21        12
# 475           21          16              San Cristóbal       21        16
# 498           22          17                Ojo De Agua       22        17
# 499           22          18                 Pellegrini       22        18
# 504           22          23                   Silipica       22        23
# 508           22          27                    Taboada       22        27
# 511           23           3                   Famaillá       23         3
# 515           23           7                    Alberdi       23         7
# 521           23          13                  Burruyacu       23        13
# 525           23          17             Tafí Del Valle       23        17
#
#        IN1   DPTO                        NOMDPTO
# 24    6077   6077                Bartolomé Mitre
# 35    6161   6161                Carmen de Areco
# 40    6196   6196               Coronel Pringles
# 41    6182   6182   Coronel de Marina L. Rosales
# 51    6266   6266          Exaltación de la Cruz
# 58    6322   6322              General La Madrid
# 59    6329   6329              General Las Heras
# 61    6315   6315         General Juan Madariaga
# 70    6014   6014         Adolfo Gonzáles Chaves
# 71    6399   6399                        Guaminí
# 73    6084   6084                  Benito Juárez
# 82    6476   6476                        Lobería
# 84    6490   6490                Lomas de Zamora
# 97    6588   6588                     9 de Julio
# 105   6651   6651                           Puán
# 116   6728   6728            San Andrés de Giles
# 117   6735   6735           San Antonio de Areco
# 129   6826   6826                Trenque Lauquen
# 132   6840   6840                Tres de Febrero
# 135   6854   6854                     25 de Mayo
# 141   6277   6277            Florentino Ameghino
# 143   6412   6412                    José C. Paz
# 147   6410   6410                      Ituzaingó
# 149   6217   6217                      Chascomús
# 151  10042  10042                        Capayán
# 160  10084  10084                          Poman
# 163  10028  10028       Antofagasta de la Sierra
# 169  14028  14028                   Cruz del Eje
# 172  14049  14049                       Ischilín
# 182  14084  14084    Presidente Roque Sáenz Peña
# 199  18119  18119             Paso de los Libres
# 201  18140  18140            San Luis del Palmar
# 208  18028  18028                     Concepción
# 209  18098  18098                      Mburucuyá
# 210  18084  18084                      Ituzaingó
# 215  18077  18077                          Itatí
# 216  18014  18014               Berón de Astrada
# 218  22126  22126                    1°  de Mayo
# 222  22119  22119        Presidencia de la Plaza
# 224  22084  22084  Libertador General San Martín
# 225  22084  22084  Libertador General San Martín
# 226  22161  22161                       Tapenagá
# 228  22098  22098          Mayor Luis J. Fontana
# 232  22168  22168                     25 de Mayo
# 236  22105  22105                     9 de Julio
# 238  22036  22036                  12 de Octubre
# 239  22039  22039                     2 de Abril
# 240  22043  22043  Fray Justo Santa María de Oro
# 251  26070  26070             Paso de los Indios
# 252  26063  26063                       Martires
# 253  26028  26028            Florentino Ameghino
# 262  30077  30077                         Nogoya
# 267  30063  30063               Islas del Ibicuy
# 278  34056  34056                         Pirane
# 279  34042  34042                        Pilagás
# 284  38021  38021            Dr. Manuel Belgrano
# 286  38056  38056                    San Antonio
# 298  38112  38112                           Yaví
# 305  42056  42056                     Chapaleufú
# 306  42063  42063                      Chical Có
# 308  42042  42042                         Curacó
# 309  42070  42070                      Guatraché
# 311  42098  42098                       Loventué
# 314  42105  42105                         Maracó
# 315  42112  42112                         Puelén
# 316  42119  42119                    Quemú Quemú
# 326  46119  46119         San Blas de los Sauces
# 329  46028  46028          Coronel Felipe Varela
# 334  46056  46056      General Angel V. Peñaloza
# 336  46070  46070         General Juan F.Quiroga
# 337  46084  46084                 General Ocampo
# 346  50063  50063                  Luján de Cuyo
# 356  50077  50077                       Malargüe
# 362  54035  54035                     Concepción
# 366  54077  54077  Libertador General San Martín
# 367  54077  54077  Libertador General San Martín
# 368  54014  54014                       Cainguás
# 369  54119  54119                     25 de Mayo
# 375  54049  54049        General Manuel Belgrano
# 388  58028  58028                    Collón Curá
# 390  58056  58056                          Lacar
# 394  62077  62077                    San Antonio
# 396  62049  62049                     9 de Julio
# 397  62091  62091                     25 de Mayo
# 399  62070  62070                     Pilnaniyeu
# 401  62063  62063                  Pichi Mahuída
# 412  66056  66056     General José de San Martín
# 419  66140  66140         Rosario de la Frontera
# 425  66147  66147               Rosario de Lerma
# 434  70063  70063                     9 de julio
# 438  70112  70112                          Ullum
# 441  70126  70126                     25 de Mayo
# 447  74056  74056                     La Capital
# 448  74021  74021               Coronel Pringles
# 449  74035  74035              General Pedernera
# 451  74063  74063  Libertador General San Martín
# 473  82077  82077                     9 de Julio
# 475  82091  82091                  San Cristobal
# 498  86126  86126                    Ojo de agua
# 499  86133  86133                      Pelegrini
# 504  86189  86189                       Silípica
# 508  86077  86077                General Taboada
# 511  90028  90028                        Famallá
# 515  90042  90042                Juan B. Alberdi
# 521  90007  90007                      Burruyacú
# 525  90098  90098                 Tafí del Valle

# %%
m = df.merge(secciones_departamentos, left_on = ['distrito_id', 'seccion_id'],
right_on = ['codprov', 'seccion_id'], how = 'inner')

electores_dpto = m.groupby(gr_eleccion + gr_cargo + ['DPTO', 'seccion_nombre'] + ['votos_tipo'])[['votos_cantidad_sum']].sum()

df_ = electores_dpto.unstack('votos_tipo')['votos_cantidad_sum'].reset_index()
# df_.groupby('DPTO').nunique()

# %%
df_.head()
# Out:
# votos_tipo   Año eleccion_tipo recuento_tipo padron_tipo  cargo_id  \
# 0           2013       GENERAL    PROVISORIO      NORMAL         3
# 1           2013       GENERAL    PROVISORIO      NORMAL         3
# 2           2013       GENERAL    PROVISORIO      NORMAL         3
# 3           2013       GENERAL    PROVISORIO      NORMAL         3
# 4           2013       GENERAL    PROVISORIO      NORMAL         3
#
# votos_tipo          cargo_nombre  DPTO seccion_nombre       0  ELECTORES  \
# 0           DIPUTADOS NACIONALES  2001      Comuna 01  7679.0   186651.0
# 1           DIPUTADOS NACIONALES  2002      Comuna 02  4452.0   149704.0
# 2           DIPUTADOS NACIONALES  2003      Comuna 03  8184.0   168252.0
# 3           DIPUTADOS NACIONALES  2004      Comuna 04  9353.0   178720.0
# 4           DIPUTADOS NACIONALES  2005      Comuna 05  7160.0   158090.0
#
# votos_tipo  IMPUGNADO    NULO  POSITIVO  RECURRIDO
# 0                49.0  1201.0  115916.0       20.0
# 1                12.0   733.0  101436.0       19.0
# 2                61.0  1265.0  109413.0       34.0
# 3                52.0  1528.0  121484.0      261.0
# 4                28.0  1128.0  111696.0       23.0

# %%
nomprovs = radio_ref[['DPTO', 'NOMDPTO', 'PROV', 'NOMPROV']].drop_duplicates().reset_index(drop = True)

# %%
data = df_.merge(dptos_p2010[['DPTO', '1 Varón', '2 Mujer', 'TOTAL']])
data = data.loc[data['Año'] == 2015]

# %%
import numpy as np

data['electores_proportion'] = data['ELECTORES']/ data['TOTAL']

(data['electores_proportion']).hist(bins = np.arange(0, 2, .02))

## Listar los departamentos con menos de X% de electores. (outliers)
outliers = data.loc[data.electores_proportion > 1.1].merge(dptos_p2010).set_index(gr_eleccion)
nomprovs.loc[nomprovs.DPTO.isin(outliers.DPTO.unique())]
# Out:
#       DPTO        NOMDPTO  PROV       NOMPROV
# 107   6553  Monte Hermoso     6  Buenos Aires
# 337  46126      Sanagasta    46      La Rioja
# 412  66077     La Caldera    66         Salta

# %%
import statsmodels.api as sm
import pandas as pd

# Calculate proportions
data['male_proportion'] = data['1 Varón'] / data['TOTAL']
data['female_proportion'] = data['2 Mujer'] / data['TOTAL']
data['positivo_proportion'] = data['POSITIVO'] / data['ELECTORES']

# Fit logistic regression model
X = data[['male_proportion', 'female_proportion']]
X = sm.add_constant(X)
y = data['positivo_proportion']

# %%
# data

# %%
data.plot(x = 'male_proportion', y = 'positivo_proportion', kind = 'scatter', alpha = .3,
xlim=(0, 1), ylim=(0, 1))
# Out:
# /home/matias/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='male_proportion', ylabel='positivo_proportion'>

# %%
logit_model = sm.Logit(y, X).fit()
display(logit_model.summary())

male_coef = logit_model.params[1]
female_coef = logit_model.params[2]

import scipy.stats as st

male_prob = st.norm.cdf(male_coef)
female_prob = st.norm.cdf(female_coef)

prob_diff = male_prob - female_prob

print(f"From the parameters in the regression, we estimate that males have {male_prob * 100:.2f}% chances of casting a vote while females have {female_prob * 100:.2f}%.")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.497943
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             Logit Regression Results
# ===============================================================================
# Dep. Variable:     positivo_proportion   No. Observations:                  525
# Model:                           Logit   Df Residuals:                      523
# Method:                            MLE   Df Model:                            1
# Date:                 Thu, 09 Feb 2023   Pseudo R-squ.:                  -3.435
# Time:                         20:36:44   Log-Likelihood:                -261.42
# converged:                        True   LL-Null:                       -58.951
# Covariance Type:             nonrobust   LLR p-value:                     1.000
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.6551        nan        nan        nan         nan         nan
# male_proportion      -0.7206        nan        nan        nan         nan         nan
# female_proportion     1.3757        nan        nan        nan         nan         nan
# =====================================================================================
# """
# From the parameters in the regression, we estimate that males have 23.56% chances of casting a vote while females have 91.55%.

# %%
# Out:
# <AxesSubplot: xlabel='Año,eleccion_tipo,recuento_tipo,padron_tipo,cargo_id,cargo_nombre'>

# %%
## Que pasa en San Juan??
## Parece que los ID de depto estuvieran mal en la data original .i.e. Rawson no tiene electores pero deberia ser el depto mas poblado.


data = df_.merge(dptos_p2010[['DPTO', 'NOMDPTO', 'NOMPROV', '1 Varón', '2 Mujer', 'TOTAL']])
# data.groupby(gr_eleccion).sum()

san_juan = data.loc[data.NOMPROV == 'San Juan'].groupby(gr_eleccion + gr_cargo ).sum()
san_juan[['ELECTORES', 'POSITIVO', 'TOTAL']].plot(ylim=(0, 700000), marker = 'o', grid=True)

import numpy as np
san_juan = data.loc[data.NOMPROV == 'San Juan'].groupby(gr_eleccion + gr_cargo + ['DPTO', 'NOMDPTO', 'seccion_nombre']).sum()[['ELECTORES', 'TOTAL']]
(san_juan['ELECTORES']/san_juan['TOTAL']).hist(bins=np.arange(0, 2, .02))

# .unstack(gr_eleccion + ['DPTO', 'NOMDPTO'])
# Out:
# <AxesSubplot: xlabel='Año,eleccion_tipo,recuento_tipo,padron_tipo,cargo_id,cargo_nombre'>

# %%
# san_juan
# Out:
#                                                                                                ELECTORES  \
# Año  eleccion_tipo recuento_tipo padron_tipo cargo_id cargo_nombre         DPTO  NOMDPTO
# 2013 GENERAL       PROVISORIO    NORMAL      3        DIPUTADOS NACIONALES 70007 Albardón        94596.0
#                                                                            70014 Angaco          38034.0
#                                                                            70021 Calingasta      57045.0
#                                                                            70028 Capital         63171.0
#                                                                            70035 Caucete          3549.0
# ...                                                                                                  ...
# 2021 PASO          PROVISORIO    NORMAL      3        DIPUTADOS NACIONALES 70105 Sarmiento       30513.0
#                                                                            70112 Ullum            6602.0
#                                                                            70119 Valle Fértil    19371.0
#                                                                            70126 25 de Mayo       7343.0
#                                                                            70133 Zonda            8298.0
#
#                                                                                                 TOTAL
# Año  eleccion_tipo recuento_tipo padron_tipo cargo_id cargo_nombre         DPTO  NOMDPTO
# 2013 GENERAL       PROVISORIO    NORMAL      3        DIPUTADOS NACIONALES 70007 Albardón       23888
#                                                                            70014 Angaco          8125
#                                                                            70021 Calingasta      8588
#                                                                            70028 Capital       109123
#                                                                            70035 Caucete        38343
# ...                                                                                               ...
# 2021 PASO          PROVISORIO    NORMAL      3        DIPUTADOS NACIONALES 70105 Sarmiento      22131
#                                                                            70112 Ullum           4886
#                                                                            70119 Valle Fértil    7222
#                                                                            70126 25 de Mayo     17119
#                                                                            70133 Zonda           4863
#
# [304 rows x 2 columns]

# %%
xx

# %%
# table = san_juan.unstack(gr_eleccion + gr_cargo)
# x = table.iloc[:,  0].sort_values()
# y = table.iloc[:, -1].sort_values()

# %%
# sorter = ('ELECTORES', 2013, 'GENERAL', 'PROVISORIO', 'NORMAL', 3, 'DIPUTADOS NACIONALES')
# sorter = ('TOTAL', 2021, 'PASO', 'PROVISORIO', 'NORMAL', 3, 'DIPUTADOS NACIONALES')
# pd.concat([x, y], axais = 1).sort_values(sorter).to_csv('test_2.csv')

# %%
# import matplotlib.pyplot as plt

# fig, axs = plt.subplots(1, figsize=(10, 10))

# x.plot(ax = axs)
# y.plot(ax = axs)

# %%
# p2010 = dptos_p2010.set_index('DPTO')['TOTAL']
# electores = df.set_index(gr_eleccion).unstack(gr_eleccion)
# yrs = electores.columns.get_level_values(u'Año').astype(str).unique()
# proy_pop_ = proy_pop[list(yrs.values)]

# %%
# votos_tipo = df.groupby(gr_eleccion + gr_cargo + gr_seccion + ['votos_tipo'])['votos_cantidad_sum'].sum().unstack('votos_tipo')
# votos_tipo[['ELECTORES', 'POSITIVO']]
